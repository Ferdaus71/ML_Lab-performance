# %% [markdown]
# <a href="https://colab.research.google.com/github/Ferdaus71/ML_Lab-performance/blob/main/ML_Lab3(EX).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('/content/diabetes.csv')
dataset.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# create scatter plot for dataset
import matplotlib.pyplot as plt
plt.scatter(dataset['Glucose'], dataset['BloodPressure'])
plt.xlabel("Glucose")
plt.ylabel("BloodPressure")
plt.title("Glucose vs BloodPressure")
plt.show()

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(regressor.intercept_)
print(regressor.coef_)
# Out:
# 2.842170943040401e-14
# [-4.69763808e-16  1.00000000e+00  1.38777878e-16  2.08166817e-16
#   6.66133815e-16 -1.03649728e-16 -7.59592042e-16 -1.11022302e-16]

# %%
y_pred = regressor.predict(X_test)
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df.head()
# Out:
#    Actual  Predicted
# 0     199      199.0
# 1     107      107.0
# 2      76       76.0
# 3     166      166.0
# 4     111      111.0

# %%
from sklearn import metrics
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
# Out:
# Mean Squared Error: 4.7223308594642294e-27
